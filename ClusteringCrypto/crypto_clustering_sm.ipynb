# %% [markdown]
# # Clustering Crypto

# %%
# !pip install -U altair

# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
#import hvplot.pandas
#import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from pathlib import Path

import altair as alt
# Out:
# Requirement already up-to-date: altair in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (4.1.0)
# Requirement already satisfied, skipping upgrade: toolz in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from altair) (0.11.1)
# Requirement already satisfied, skipping upgrade: numpy in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from altair) (1.17.0)
# Requirement already satisfied, skipping upgrade: jinja2 in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from altair) (2.11.2)
# Requirement already satisfied, skipping upgrade: entrypoints in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from altair) (0.3)
# Requirement already satisfied, skipping upgrade: pandas>=0.18 in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from altair) (1.1.3)
# Requirement already satisfied, skipping upgrade: jsonschema in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from altair) (3.2.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from pandas>=0.18->altair) (2020.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from jsonschema->altair) (2.0.0)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from jsonschema->altair) (20.3.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from jsonschema->altair) (0.17.3)
# Requirement already satisfied, skipping upgrade: six>=1.11.0 in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from jsonschema->altair) (1.15.0)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from jsonschema->altair) (50.3.1.post20201107)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in c:\users\tsanp\.conda\envs\mlenv\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->altair) (3.4.0)

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"
response = requests.get(url)
content = response.json()

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.
crypto_df = pd.DataFrame.from_dict(content["Data"], orient="index")
crypto_df.columns
# Out:
# Index(['Id', 'Url', 'ImageUrl', 'ContentCreatedOn', 'Name', 'Symbol',
#        'CoinName', 'FullName', 'Description', 'AssetTokenStatus', 'Algorithm',
#        'ProofType', 'SortOrder', 'Sponsored', 'Taxonomy', 'Rating',
#        'IsTrading', 'TotalCoinsMined', 'BlockNumber', 'NetHashesPerSecond',
#        'BlockReward', 'BlockTime', 'AssetLaunchDate', 'MaxSupply',
#        'MktCapPenalty', 'PlatformType', 'BuiltOn', 'SmartContractAddress',
#        'DecimalPoints', 'Difficulty', 'IsUsedInDefi'],
#       dtype='object')

# %%
# Alternatively, use the provided csv file:
# Using csv file, because API call doesn't return "TotalCoinSupply".
#file_path = Path("Resources/crypto_data.csv")
# Create a DataFrame
#crypto_df = pd.read_csv(file_path).rename(columns={"Unnamed: 0":"ID"})
#crypto_df = crypto_df.set_index(crypto_df["ID"]).drop(columns="ID")
#crypto_df.head()

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
#drop_columns = crypto_df.columns.drop(['CoinName','Algorithm','IsTrading','ProofType','MaxSupply','TotalCoinSupply'])
crypto_df = crypto_df.rename(columns={"MaxSupply":"TotalCoinSupply"})
drop_columns = crypto_df.columns.drop(['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'])
crypto_df = crypto_df.drop(columns=drop_columns)
print(f"Total Rows: {len(crypto_df):0.0f}")
crypto_df.head()
# Out:
# Total Rows: 5772
#       CoinName Algorithm ProofType  IsTrading  TotalCoinsMined  \
# 42     42 Coin    Scrypt   PoW/PoS       True              0.0
# 300  300 token       N/A       N/A       True            300.0
# 365    365Coin       X11   PoW/PoS       True              0.0
# 404    404Coin    Scrypt   PoW/PoS       True              0.0
# 433  433 Token       N/A       N/A      False              NaN
#
#      TotalCoinSupply
# 42               0.0
# 300            300.0
# 365              0.0
# 404              0.0
# 433              NaN

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df[crypto_df.IsTrading==True]
print(f"Total Rows: {len(crypto_df):0.0f}")
crypto_df.head()
# Out:
# Total Rows: 4650
#       CoinName Algorithm ProofType  IsTrading  TotalCoinsMined  \
# 42     42 Coin    Scrypt   PoW/PoS       True              0.0
# 300  300 token       N/A       N/A       True            300.0
# 365    365Coin       X11   PoW/PoS       True              0.0
# 404    404Coin    Scrypt   PoW/PoS       True              0.0
# 611  SixEleven   SHA-256       PoW       True              0.0
#
#      TotalCoinSupply
# 42               0.0
# 300            300.0
# 365              0.0
# 404              0.0
# 611              0.0

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df[crypto_df.Algorithm!="N/A"]
print(f"Total Rows: {len(crypto_df):0.0f}")
crypto_df.head()
# Out:
# Total Rows: 1473
#       CoinName Algorithm ProofType  IsTrading  TotalCoinsMined  \
# 42     42 Coin    Scrypt   PoW/PoS       True              0.0
# 365    365Coin       X11   PoW/PoS       True              0.0
# 404    404Coin    Scrypt   PoW/PoS       True              0.0
# 611  SixEleven   SHA-256       PoW       True              0.0
# 808        808   SHA-256   PoW/PoS       True              0.0
#
#      TotalCoinSupply
# 42               0.0
# 365              0.0
# 404              0.0
# 611              0.0
# 808              0.0

# %%
# Remove the "IsTrading" column
crypto_df = crypto_df.drop(columns=["IsTrading"])
print(f"Total Rows: {len(crypto_df):0.0f}")
crypto_df.head()
# Out:
# Total Rows: 1473
#       CoinName Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# 42     42 Coin    Scrypt   PoW/PoS              0.0              0.0
# 365    365Coin       X11   PoW/PoS              0.0              0.0
# 404    404Coin    Scrypt   PoW/PoS              0.0              0.0
# 611  SixEleven   SHA-256       PoW              0.0              0.0
# 808        808   SHA-256   PoW/PoS              0.0              0.0

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna()
print(f"Total Rows: {len(crypto_df):0.0f}")
crypto_df.head()
# Out:
# Total Rows: 162
#       CoinName Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# 42     42 Coin    Scrypt   PoW/PoS              0.0              0.0
# 365    365Coin       X11   PoW/PoS              0.0              0.0
# 404    404Coin    Scrypt   PoW/PoS              0.0              0.0
# 611  SixEleven   SHA-256       PoW              0.0              0.0
# 808        808   SHA-256   PoW/PoS              0.0              0.0

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df[crypto_df.TotalCoinsMined>0]
print(f"Total Rows: {len(crypto_df):0.0f}")
crypto_df.head()
# Out:
# Total Rows: 107
#             CoinName Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# NVC         NovaCoin    Scrypt   PoW/PoS     3.075844e+06             -1.0
# XCP     CounterParty   SHA-256       PoW     2.615225e+06             -1.0
# NSR         NuShares       PoS       PoS     5.849637e+09              0.0
# MONA        MonaCoin    Scrypt       PoW     7.996224e+07             -1.0
# TRI   Triangles Coin       X13   PoW/PoS     1.661090e+05              0.0

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[crypto_df.ProofType!="N/A"]
print(f"Total Rows: {len(crypto_df):0.0f}")
crypto_df.head()
# Out:
# Total Rows: 95
#             CoinName Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# NVC         NovaCoin    Scrypt   PoW/PoS     3.075844e+06             -1.0
# XCP     CounterParty   SHA-256       PoW     2.615225e+06             -1.0
# NSR         NuShares       PoS       PoS     5.849637e+09              0.0
# MONA        MonaCoin    Scrypt       PoW     7.996224e+07             -1.0
# TRI   Triangles Coin       X13   PoW/PoS     1.661090e+05              0.0

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coinName_df = crypto_df.CoinName
coinName_df.head()
# Out:
# NVC           NovaCoin
# XCP       CounterParty
# NSR           NuShares
# MONA          MonaCoin
# TRI     Triangles Coin
# Name: CoinName, dtype: object

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop(columns=["CoinName"])
crypto_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# NVC     Scrypt   PoW/PoS     3.075844e+06             -1.0
# XCP    SHA-256       PoW     2.615225e+06             -1.0
# NSR        PoS       PoS     5.849637e+09              0.0
# MONA    Scrypt       PoW     7.996224e+07             -1.0
# TRI        X13   PoW/PoS     1.661090e+05              0.0

# %%
# Create dummy variables for text features
X = pd.get_dummies(crypto_df, columns=["Algorithm", "ProofType"])
X.head()
# Out:
#       TotalCoinsMined  TotalCoinSupply  Algorithm_BEP2 Token  \
# NVC      3.075844e+06             -1.0                     0
# XCP      2.615225e+06             -1.0                     0
# NSR      5.849637e+09              0.0                     0
# MONA     7.996224e+07             -1.0                     0
# TRI      1.661090e+05              0.0                     0
#
#       Algorithm_BLAKE256  Algorithm_BMW512 / Echo512  Algorithm_Blake2b  \
# NVC                    0                           0                  0
# XCP                    0                           0                  0
# NSR                    0                           0                  0
# MONA                   0                           0                  0
# TRI                    0                           0                  0
#
#       Algorithm_C31  Algorithm_CryptoNight  Algorithm_CryptoNight-Heavy  \
# NVC               0                      0                            0
# XCP               0                      0                            0
# NSR               0                      0                            0
# MONA              0                      0                            0
# TRI               0                      0                            0
#
#       Algorithm_CryptoNight-Lite  ...  ProofType_PoS/LPoS  ProofType_PoSA  \
# NVC                            0  ...                   0               0
# XCP                            0  ...                   0               0
# NSR                            0  ...                   0               0
# MONA                           0  ...                   0               0
# TRI                            0  ...                   0               0
#
#       ProofType_PoW  ProofType_PoW/PoS  ProofType_PoW/PoSe  \
# NVC               0                  1                   0
# XCP               1                  0                   0
# NSR               0                  0                   0
# MONA              1                  0                   0
# TRI               0                  1                   0
#
#       ProofType_PoW/nPoS  ProofType_Proof of Authority  ProofType_SPoS  \
# NVC                    0                             0               0
# XCP                    0                             0               0
# NSR                    0                             0               0
# MONA                   0                             0               0
# TRI                    0                             0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# NVC                                0                   0
# XCP                                0                   0
# NSR                                0                   0
# MONA                               0                   0
# TRI                                0                   0
#
# [5 rows x 62 columns]

# %%
# Standardize data
std_scaler = StandardScaler()
std_scaler.fit(X)
X_scaled = pd.DataFrame(std_scaler.transform(X))
X_scaled.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.162711 -0.139858 -0.103142 -0.146647 -0.103142 -0.146647 -0.146647
# 1 -0.162715 -0.139858 -0.103142 -0.146647 -0.103142 -0.146647 -0.146647
# 2 -0.106183 -0.139858 -0.103142 -0.146647 -0.103142 -0.146647 -0.146647
# 3 -0.161968 -0.139858 -0.103142 -0.146647 -0.103142 -0.146647 -0.146647
# 4 -0.162739 -0.139858 -0.103142 -0.146647 -0.103142 -0.146647 -0.146647
#
#          7         8         9   ...        52        53        54        55  \
# 0 -0.146647 -0.103142 -0.103142  ... -0.103142 -0.103142 -0.968904  1.877181
# 1 -0.146647 -0.103142 -0.103142  ... -0.103142 -0.103142  1.032094 -0.532714
# 2 -0.146647 -0.103142 -0.103142  ... -0.103142 -0.103142 -0.968904 -0.532714
# 3 -0.146647 -0.103142 -0.103142  ... -0.103142 -0.103142  1.032094 -0.532714
# 4 -0.146647 -0.103142 -0.103142  ... -0.103142 -0.103142 -0.968904  1.877181
#
#          56        57        58        59        60        61
# 0 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142
# 1 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142
# 2 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142
# 3 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142
# 4 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142 -0.103142
#
# [5 rows x 62 columns]

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_scaled)

# %%
# Create a DataFrame with the principal components data
pcs_df = pd.DataFrame(data=X_pca, 
                      index=crypto_df.index, 
                      columns=["PC1", "PC2", "PC3"])
pcs_df.head()
# Out:
#            PC1       PC2       PC3
# NVC  -0.380114 -1.167690 -1.779028
# XCP  -0.473714  1.610627  0.037106
# NSR  -0.170034 -1.066450  1.010253
# MONA -0.453239  0.904984 -0.542260
# TRI  -0.357015 -1.983805 -2.300397

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
#df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
alt.Chart(df_elbow).mark_line().encode(
    x = "k",
    y = "inertia").properties(title = "Elbow Curve")
# Out:
# alt.Chart(...)

# %% [markdown]
# Running K-Means with `k=4`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)
# Fit the model
model.fit(pcs_df)
# Predict clusters
predictions = model.predict(pcs_df)
# Create a new DataFrame including predicted clusters and cryptocurrencies features
cluster_df = pd.concat([crypto_df, pcs_df, coinName_df], axis="columns", join="inner")
cluster_df["Class"] = model.labels_
cluster_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined  TotalCoinSupply       PC1  \
# NVC     Scrypt   PoW/PoS     3.075844e+06             -1.0 -0.380114
# XCP    SHA-256       PoW     2.615225e+06             -1.0 -0.473714
# NSR        PoS       PoS     5.849637e+09              0.0 -0.170034
# MONA    Scrypt       PoW     7.996224e+07             -1.0 -0.453239
# TRI        X13   PoW/PoS     1.661090e+05              0.0 -0.357015
#
#            PC2       PC3        CoinName  Class
# NVC  -1.167690 -1.779028        NovaCoin      0
# XCP   1.610627  0.037106    CounterParty      1
# NSR  -1.066450  1.010253        NuShares      2
# MONA  0.904984 -0.542260        MonaCoin      1
# TRI  -1.983805 -2.300397  Triangles Coin      0

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 3D-Scatter with the PCA data and the clusters
alt.Chart(cluster_df).mark_circle().encode(
    x = "PC1",
    y = "PC2",
    tooltip = ["CoinName", "Algorithm", "TotalCoinsMined", "TotalCoinSupply"]
).properties(title = "PC1 PC2 Clusters").interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
# ["CoinName", "Algorithm", "ProofType", "TotalCoinsMined", "TotalCoinSupply"]
base = alt.Chart(cluster_df).mark_text().encode(
    y=alt.Y('row_number:O',axis=None)
).transform_window(
    row_number='row_number()'
)

# Data Tables
coin_name = base.encode(text="CoinName").properties(title="CoinName", width = 100)
algo = base.encode(text="Algorithm").properties(title="Algorithm", width = 100)
proof = base.encode(text="ProofType").properties(title="ProofType", width = 100)
mined = base.encode(text="TotalCoinsMined").properties(title="TotalCoinsMined", width = 100)
supply = base.encode(text="TotalCoinSupply").properties(title="TotalCoinSupply", width = 100)
text = alt.hconcat(coin_name, algo, proof, mined, supply) # Combine data tables

text.display()
# Out:
# alt.HConcatChart(...)

# %%
# Print the total number of tradable cryptocurrencies
print(f"There are total of {len(cluster_df)} tradable cryptocurrencies.")
# Out:
# There are total of 95 tradable cryptocurrencies.

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
#cluster_df["TotalCoinSupply"] = cluster_df.apply(lambda x: int(x["TotalCoinSupply"]))
#cluster_df = cluster_df[cluster_df.TotalCoinSupply != 0]
#type(cluster_df.iloc[0]["TotalCoinSupply"])
cluster_df.loc["BTT"]
# Out:
# Algorithm                TRC10
# ProofType                 DPoS
# TotalCoinsMined    9.89989e+11
# TotalCoinSupply        9.9e+11
# PC1                    16.5525
# PC2                     1.1872
# PC3                  -0.873798
# CoinName            BitTorrent
# Class                        3
# Name: BTT, dtype: object

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
alt.Chart(cluster_df).mark_circle().encode(
    x = "TotalCoinsMined",
    y = "TotalCoinSupply",
    tooltip = ["CoinName", "Algorithm", "TotalCoinsMined", "TotalCoinSupply"]
).interactive()
# Out:
# alt.Chart(...)
